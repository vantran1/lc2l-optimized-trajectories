# %% [markdown]
# # Trajectory Optimization

# %% [markdown]
# This jupyter notebook is the main trajectory optimization notebook used in Van Tran's thesis.

# %% [markdown]
# ## Main Run

# %%
import openap
from openap import top
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Outage and Risk Objective Function Setup

# %%
# Load the CSV data into a Pandas DataFrame
csv_file_path = "data/cost/40_outage_data.csv"  # Replace with your file path
outage_likelihood_data = pd.read_csv(csv_file_path)

# Extract unique values of latitude, longitude, and altitude
latitudes = outage_likelihood_data['Latitude'].unique()
longitudes = outage_likelihood_data['Longitude'].unique()
altitudes = outage_likelihood_data['Altitude'].unique()

# Sort unique values to ensure proper indexing
latitudes = np.sort(latitudes)
longitudes = np.sort(longitudes)
altitudes = np.sort(altitudes)

# Create a 3D matrix for outage likelihood values
outage_likelihood_values = np.full((len(latitudes), len(longitudes), len(altitudes)), np.nan)

# Populate the 3D matrix with outage probabilities
for _, row in outage_likelihood_data.iterrows():
    lat_idx = np.where(latitudes == row['Latitude'])[0][0]
    lon_idx = np.where(longitudes == row['Longitude'])[0][0]
    alt_idx = np.where(altitudes == row['Altitude'])[0][0]
    outage_likelihood_values[lat_idx, lon_idx, alt_idx] = row['Outage']

# Verify the shape of the resulting 3D matrix
print("Shape of outage likelihood matrix:", outage_likelihood_values.shape)
# Out:
# Shape of outage likelihood matrix: (351, 751, 31)

# %%
lons, lats, alts = np.meshgrid(longitudes, latitudes, altitudes)
likelihood_cost_3d = pd.DataFrame(
    np.array([lons, lats, alts, outage_likelihood_values]).reshape(4, -1).T,
    columns=["longitude", "latitude", "altitude", "cost"],
).assign(height=lambda x: x.altitude * 0.3048)

likelihood_cost_3d
# Out:
#          longitude  latitude  altitude  cost  height
# 0           -130.0      20.0       0.0   1.0     0.0
# 1           -130.0      20.0    1000.0   1.0   304.8
# 2           -130.0      20.0    2000.0   1.0   609.6
# 3           -130.0      20.0    3000.0   1.0   914.4
# 4           -130.0      20.0    4000.0   1.0  1219.2
# ...            ...       ...       ...   ...     ...
# 8171626      -60.0      55.0   26000.0   1.0  7924.8
# 8171627      -60.0      55.0   27000.0   1.0  8229.6
# 8171628      -60.0      55.0   28000.0   1.0  8534.4
# 8171629      -60.0      55.0   29000.0   1.0  8839.2
# 8171630      -60.0      55.0   30000.0   1.0  9144.0
#
# [8171631 rows x 5 columns]

# %%
# Load the CSV data into a Pandas DataFrame
csv_file_path = 'data/cost/40_risk_data.csv' # Replace with your file path
risk_data = pd.read_csv(csv_file_path)

# Extract unique values of latitude, longitude, and altitude
latitudes = risk_data['Latitude'].unique()
longitudes = risk_data['Longitude'].unique()
altitudes = risk_data['Altitude'].unique()

# Sort unique values to ensure proper indexing
latitudes = np.sort(latitudes)
longitudes = np.sort(longitudes)
altitudes = np.sort(altitudes)

# Create a 3D matrix for outage likelihood values
risk_values = np.full((len(latitudes), len(longitudes), len(altitudes)), np.nan)

# Populate the 3D matrix with outage probabilities
for _, row in risk_data.iterrows():
    lat_idx = np.where(latitudes == row['Latitude'])[0][0]
    lon_idx = np.where(longitudes == row['Longitude'])[0][0]
    alt_idx = np.where(altitudes == row['Altitude'])[0][0]
    risk_values[lat_idx, lon_idx, alt_idx] = row['Risk']

# Verify the shape of the resulting 3D matrix
print("Shape of risk matrix:", risk_values.shape)
# Out:
# Shape of risk matrix: (351, 701, 31)

# %%
lons, lats, alts = np.meshgrid(longitudes, latitudes, altitudes)
risk_cost_3d = pd.DataFrame(
    np.array([lons, lats, alts, risk_values]).reshape(4, -1).T,
    columns=["longitude", "latitude", "altitude", "cost"],
).assign(height=lambda x: x.altitude * 0.3048)

risk_cost_3d
# Out:
#          longitude  latitude  altitude  cost  height
# 0           -130.0      20.0       0.0   0.0     0.0
# 1           -130.0      20.0    1000.0   0.0   304.8
# 2           -130.0      20.0    2000.0   0.0   609.6
# 3           -130.0      20.0    3000.0   0.0   914.4
# 4           -130.0      20.0    4000.0   0.0  1219.2
# ...            ...       ...       ...   ...     ...
# 7627576      -60.0      55.0   26000.0   0.0  7924.8
# 7627577      -60.0      55.0   27000.0   0.0  8229.6
# 7627578      -60.0      55.0   28000.0   0.0  8534.4
# 7627579      -60.0      55.0   29000.0   0.0  8839.2
# 7627580      -60.0      55.0   30000.0   0.0  9144.0
#
# [7627581 rows x 5 columns]

# %% [markdown]
# ## Main Run for Flight Profile Extraction

# %%
import os

mass_takeoff_assumed = 66300  # Assumed takeoff fuel mass (kg)
fuelflow = openap.FuelFlow("A320") # Assumed aircraft

# Setting up objective functions
likelihood_interpolant = top.tools.interpolant_from_dataframe(likelihood_cost_3d)
risk_interpolant = top.tools.interpolant_from_dataframe(risk_cost_3d)

def objective(x, u, dt, **kwargs):
    """The final objective is the grid cost"""
    grid_cost = optimizer.obj_grid_cost(x, u, dt, time_dependent=True, **kwargs)
    return grid_cost

# Define your unique OD_pair_file
unique_OD_pair_file = 'data/misc/DFW_unique_OD_pairs.csv'

# Load the dataset
df = pd.read_csv(unique_OD_pair_file)

# Counters for total flights and successfully processed flights
total_flights = 0
successful_flights = 0

# Loop through rows in the file
for _, row in df.iterrows():
    # Increment flight count
    total_flights += 1

    # Extract origin and destination
    origin = row['Origin']
    destination = row['Destination']

    print(f"Processing flight {origin} to {destination}...")

    # Initialize optimizer for this flight
    optimizer = top.CompleteFlight("A320", origin, destination, m0=0.85)

    # Step 1: Optimize for risk
    risk_optimal_flight = optimizer.trajectory(objective=objective, interpolant=risk_interpolant)
    if risk_optimal_flight is None:
        print(f"Skipping Flight {origin} to {destination}: Risk optimization returned None.")
        continue

    # Step 2: Optimize for likelihood
    likelihood_optimal_flight = optimizer.trajectory(objective=objective, interpolant=likelihood_interpolant)
    if likelihood_optimal_flight is None:
        print(f"Skipping Flight {origin} to {destination}: Likelihood optimization returned None.")
        continue

    # Step 3: Optimize for fuel
    fuel_optimal_flight = optimizer.trajectory(objective="fuel")
    if fuel_optimal_flight is None:
        print(f"Skipping Flight {origin} to {destination}: Fuel optimization returned None.")
        continue

    # Increment successful flight count
    successful_flights += 1

    # Store results for each regime
    for regime, flight in {
        "risk": risk_optimal_flight,
        "likelihood": likelihood_optimal_flight,
        "fuel": fuel_optimal_flight,
    }.items():
        # Save each flight's trajectory to CSV
        output_folder = "data/flight_trajectories/40dB"
        os.makedirs(output_folder, exist_ok=True)  # Create the folder if it doesn't exist

        for regime, flight in {
            "risk": risk_optimal_flight,
            "likelihood": likelihood_optimal_flight,
            "fuel": fuel_optimal_flight,
        }.items():
            filename = f"{origin}_{destination}_{regime}_40_trajectory.csv"
            filepath = os.path.join(output_folder, filename)
            flight.to_csv(filepath, index=False)

# Calculate the percentage of successful flights
if total_flights > 0:
    success_rate = (successful_flights / total_flights) * 100
else:
    success_rate = 0

print(f"Processed {successful_flights}/{total_flights} flights successfully.")
print(f"Success Rate: {success_rate:.2f}%")
# Out:
# Processing flight KAFW to KMCI...
# CasADi - 2025-03-26 18:42:15 WARNING("KeyboardInterruptException") [.../casadi/interfaces/ipopt/ipopt_nlp.cpp:114]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <function DM.<lambda> at 0x124120c20> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <function DM.<lambda> at 0x124120c20> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <function DM.<lambda> at 0x124120c20> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <function DM.<lambda> at 0x124120c20> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <function DM.<lambda> at 0x124120c20> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <function DM.<lambda> at 0x124120c20> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /var/folders/25/0tv79pt55sjbzzw_4r3y61380000gn/T/ipykernel_45888/125123458.py in ?()
#      48         print(f"Skipping Flight {origin} to {destination}: Likelihood optimization returned None.")
#      49         continue
#      50
#      51     # Step 3: Optimize for fuel
# ---> 52     fuel_optimal_flight = optimizer.trajectory(objective="fuel")
#      53     if fuel_optimal_flight is None:
#      54         print(f"Skipping Flight {origin} to {destination}: Fuel optimization returned None.")
#      55         continue
#
# ~/opt/anaconda3/envs/openap3.0/lib/python3.13/site-packages/openap/top/full.py in ?(self, objective, **kwargs)
#     343         nlp = {"f": J, "x": w, "g": g}
#     344
#     345         self.solver = ca.nlpsol("solver", "ipopt", nlp, self.solver_options)
#     346
# --> 347         self.solution = self.solver(x0=w0, lbx=lbw, ubx=ubw, lbg=lbg, ubg=ubg)
#     348
#     349         if not self.solver.stats()["success"]:
#     350             warnings.warn("optimization failed")
#
# ~/opt/anaconda3/envs/openap3.0/lib/python3.13/site-packages/casadi/casadi.py in ?(self, *args, **kwargs)
#   23552         else:
#   23553           return tuple(ret)
#   23554       else:
#   23555     # Named inputs -> return dictionary
# > 23556         return self.call(kwargs)
#
# ~/opt/anaconda3/envs/openap3.0/lib/python3.13/site-packages/casadi/casadi.py in ?(self, *args)
#   20201
#   20202
#   20203
#   20204         """
# > 20205         return _casadi.Function_call(self, *args)
#
# SystemError: <built-in function Function_call> returned a result with an exception set

# %% [markdown]
# ## Main Run for Fuel Calculation

# %%
mass_takeoff_assumed = 66300  # Assumed takeoff fuel mass (kg)
fuelflow = openap.FuelFlow("A320") # Assumed aircraft

# Setting up objective functions
likelihood_interpolant = top.tools.interpolant_from_dataframe(likelihood_cost_3d)
risk_interpolant = top.tools.interpolant_from_dataframe(risk_cost_3d)

def objective(x, u, dt, **kwargs):
    """The final objective is the grid cost"""
    grid_cost = optimizer.obj_grid_cost(x, u, dt, time_dependent=True, **kwargs)
    return grid_cost

# Define your unique OD_pair_file
unique_OD_pair_file = 'data/misc/DFW_unique_OD_pairs.csv'

# Load the dataset
df = pd.read_csv(unique_OD_pair_file)

# Lists to store total fuel for all regimes
fuel_burns_by_regime = {
    "fuel": [],
    "likelihood": [],
    "risk": []
}

time_in_flight_by_regime = {
    "fuel": [],
    "likelihood": [],
    "risk": []
}

# Counters for total flights and successfully processed flights
total_flights = 0
successful_flights = 0

# Loop through rows in the file
for _, row in df.iterrows():
    # Increment flight count
    total_flights += 1

    # Extract origin and destination
    origin = row['Origin']
    destination = row['Destination']

    print(f"Processing flight {origin} to {destination}...")

    # Initialize optimizer for this flight
    optimizer = top.CompleteFlight("A320", origin, destination, m0=0.85)

    # Step 1: Optimize for risk
    risk_optimal_flight = optimizer.trajectory(objective=objective, interpolant=risk_interpolant)
    if risk_optimal_flight is None:
        print(f"Skipping Flight {origin} to {destination}: Risk optimization returned None.")
        continue

    # Step 2: Optimize for likelihood
    likelihood_optimal_flight = optimizer.trajectory(objective=objective, interpolant=likelihood_interpolant)
    if likelihood_optimal_flight is None:
        print(f"Skipping Flight {origin} to {destination}: Likelihood optimization returned None.")
        continue

    # Step 3: Optimize for fuel
    fuel_optimal_flight = optimizer.trajectory(objective="fuel")
    if fuel_optimal_flight is None:
        print(f"Skipping Flight {origin} to {destination}: Fuel optimization returned None.")
        continue

    # Increment successful flight count
    successful_flights += 1

    # Store results for each regime
    for regime, flight in {
        "risk": risk_optimal_flight,
        "likelihood": likelihood_optimal_flight,
        "fuel": fuel_optimal_flight,
    }.items():
        # Ensure flight data exists
        if 'ts' not in flight.columns:
            print(f"Skipping {regime} optimization for {origin} to {destination}: No time series data found.")
            continue
            
        # Convert time from seconds to minutes
        total_time = max(flight['ts']) / 60  
        time_in_flight_by_regime[regime].append(total_time)

        # Compute time step differences
        flight = flight.assign(d_ts=flight['ts'].diff().fillna(0))

        # Initialize lists for fuel flow calculations
        fuelflow_every_step = []
        fuel_every_step = []
        mass_current = mass_takeoff_assumed  # Start with takeoff mass

        # Calculate fuel burn for the trajectory
        for _, row in flight.iterrows():
            ff = fuelflow.enroute(
                mass=mass_current,
                tas=row.tas,
                alt=row.altitude,
                vs=row.vertical_rate,
            )
            fuel = ff * row.d_ts
            fuelflow_every_step.append(ff)
            fuel_every_step.append(fuel)
            mass_current -= fuel

        # Calculate total fuel burn
        total_fuel = sum(fuel_every_step)
        fuel_burns_by_regime[regime].append(total_fuel)
    
    if total_flights == 3:
        break

# Calculate the percentage of successful flights
if total_flights > 0:
    success_rate = (successful_flights / total_flights) * 100
else:
    success_rate = 0

print(f"Processed {successful_flights}/{total_flights} flights successfully.")
print(f"Success Rate: {success_rate:.2f}%")
# Out:
# Processing flight KAFW to KMCI...
# Skipping Flight KAFW to KMCI: Risk optimization returned None.
# Processing flight KDFW to KAFW...
# Skipping Flight KDFW to KAFW: Risk optimization returned None.
# Processing flight KAFW to KMFE...
# Skipping Flight KAFW to KMFE: Risk optimization returned None.
# Processing flight KDFW to KGSO...
# Skipping Flight KDFW to KGSO: Risk optimization returned None.
# Processing flight KAFW to KCVG...
# Skipping Flight KAFW to KCVG: Risk optimization returned None.
# Processing flight KAFW to KMIA...
# Skipping Flight KAFW to KMIA: Risk optimization returned None.
# Processing flight KAFW to KMSY...
# Processing flight KAFW to MROC...
# Skipping Flight KAFW to MROC: Risk optimization returned None.
# Processing flight KAFW to KIDA...
# Skipping Flight KAFW to KIDA: Risk optimization returned None.
# Processing flight KDFW to KPDX...
# Skipping Flight KDFW to KPDX: Risk optimization returned None.
# Processing flight KAFW to KJFK...
# Skipping Flight KAFW to KJFK: Risk optimization returned None.
# Processing flight KDFW to KRFD...
# Skipping Flight KDFW to KRFD: Risk optimization returned None.
# Processing flight KAFW to KPIT...
# Skipping Flight KAFW to KPIT: Risk optimization returned None.
# Processing flight KAFW to KBNA...
# Processing flight KAFW to KSKF...
# Skipping Flight KAFW to KSKF: Risk optimization returned None.
# Processing flight KDAL to KSDF...
# Skipping Flight KDAL to KSDF: Risk optimization returned None.
# Processing flight KDFW to RKSI...
# CasADi - 2025-03-06 07:46:47 WARNING("solver:nlp_grad_f failed: NaN detected for output grad_f_x, at (row 5, col 0).") [.../casadi/core/oracle_function.cpp:393]
# Skipping Flight KDFW to RKSI: Risk optimization returned None.
# Processing flight KAFW to KDSM...
# Skipping Flight KAFW to KDSM: Fuel optimization returned None.
# Processing flight KAFW to KABE...
# Skipping Flight KAFW to KABE: Risk optimization returned None.
# Processing flight KAFW to KOKC...
# Skipping Flight KAFW to KOKC: Likelihood optimization returned None.
# Processing flight KAFW to KBDL...
# Skipping Flight KAFW to KBDL: Risk optimization returned None.
# Processing flight KAFW to KTOL...
# Skipping Flight KAFW to KTOL: Risk optimization returned None.
# Processing flight KAFW to KGEG...
# Skipping Flight KAFW to KGEG: Risk optimization returned None.
# Processing flight KAFW to KABQ...
# Skipping Flight KAFW to KABQ: Fuel optimization returned None.
# Processing flight KAFW to KEWR...
# Skipping Flight KAFW to KEWR: Risk optimization returned None.
# Processing flight KDAL to MMSP...
# Skipping Flight KDAL to MMSP: Risk optimization returned None.
# Processing flight KDFW to KTUL...
# Skipping Flight KDFW to KTUL: Risk optimization returned None.
# Processing flight KDFW to KGYY...
# Skipping Flight KDFW to KGYY: Risk optimization returned None.
# Processing flight KDFW to KMCI...
# Skipping Flight KDFW to KMCI: Risk optimization returned None.
# Processing flight KDFW to KLAX...
# Skipping Flight KDFW to KLAX: Risk optimization returned None.
# Processing flight KAFW to KRIV...
# Skipping Flight KAFW to KRIV: Risk optimization returned None.
# Processing flight KDFW to KMFE...
# Skipping Flight KDFW to KMFE: Risk optimization returned None.
# Processing flight KDFW to KCVG...
# Skipping Flight KDFW to KCVG: Risk optimization returned None.
# Processing flight KDAL to KDRT...
# Skipping Flight KDAL to KDRT: Risk optimization returned None.
# Processing flight KAFW to CYQB...
# Skipping Flight KAFW to CYQB: Risk optimization returned None.
# Processing flight KDAL to KOGD...
# Skipping Flight KDAL to KOGD: Risk optimization returned None.
# Processing flight KAFW to KONT...
# Processing flight KAFW to KYIP...
# Skipping Flight KAFW to KYIP: Risk optimization returned None.
# Processing flight KAFW to KRIC...
# Skipping Flight KAFW to KRIC: Risk optimization returned None.
# Processing flight KAFW to KSAT...
# Skipping Flight KAFW to KSAT: Likelihood optimization returned None.
# Processing flight KDFW to KJFK...
# Skipping Flight KDFW to KJFK: Risk optimization returned None.
# Processing flight KAFW to KMEM...
# Processing flight KAFW to KIND...
# Skipping Flight KAFW to KIND: Risk optimization returned None.
# Processing flight KAFW to KCPR...
# Processing flight KDFW to KARA...
# Skipping Flight KDFW to KARA: Risk optimization returned None.
# Processing flight KAFW to KLAS...
# Skipping Flight KAFW to KLAS: Risk optimization returned None.
# Processing flight KAFW to PANC...
# Skipping Flight KAFW to PANC: Risk optimization returned None.
# Processing flight KAFW to KMAF...
# Skipping Flight KAFW to KMAF: Risk optimization returned None.
# Processing flight KDAL to KHTS...
# Skipping Flight KDAL to KHTS: Risk optimization returned None.
# Processing flight KAFW to KCLT...
# Skipping Flight KAFW to KCLT: Risk optimization returned None.
# Processing flight KDAL to KLPR...
# Skipping Flight KDAL to KLPR: Risk optimization returned None.
# Processing flight KAFW to KOAK...
# Skipping Flight KAFW to KOAK: Risk optimization returned None.
# Processing flight KAFW to KSLC...
# Skipping Flight KAFW to KSLC: Risk optimization returned None.
# Processing flight KAFW to KATL...
# Processing flight KAFW to KLAL...
# Skipping Flight KAFW to KLAL: Risk optimization returned None.
# Processing flight KAFW to MMQT...
# Skipping Flight KAFW to MMQT: Risk optimization returned None.
# Processing flight KAFW to KTPA...
# Skipping Flight KAFW to KTPA: Risk optimization returned None.
# Processing flight KAFW to KSMF...
# Skipping Flight KAFW to KSMF: Risk optimization returned None.
# Processing flight KAFW to KLBB...
# Skipping Flight KAFW to KLBB: Risk optimization returned None.
# Processing flight KDAL to KSUS...
# Skipping Flight KDAL to KSUS: Risk optimization returned None.
# Processing flight KDAL to KBUF...
# Skipping Flight KDAL to KBUF: Risk optimization returned None.
# Processing flight KDFW to KOKC...
# Processing flight KAFW to KCOE...
# Skipping Flight KAFW to KCOE: Risk optimization returned None.
# Processing flight KDFW to KBDL...
# Skipping Flight KDFW to KBDL: Risk optimization returned None.
# Processing flight KAFW to KSTL...
# Skipping Flight KAFW to KSTL: Risk optimization returned None.
# Processing flight KDFW to KABQ...
# Processing flight KDAL to KIAG...
# Skipping Flight KDAL to KIAG: Risk optimization returned None.
# Processing flight KDFW to KEWR...
# Skipping Flight KDFW to KEWR: Risk optimization returned None.
# Processing flight KDFW to KHSV...
# Skipping Flight KDFW to KHSV: Risk optimization returned None.
# Processing flight KAFW to KFLL...
# Skipping Flight KAFW to KFLL: Risk optimization returned None.
# Processing flight KAFW to KIAH...
# Skipping Flight KAFW to KIAH: Risk optimization returned None.
# Processing flight KDFW to KONT...
# Processing flight KDFW to KMIA...
# Skipping Flight KDFW to KMIA: Risk optimization returned None.
# Processing flight KDFW to KMEM...
# Skipping Flight KDFW to KMEM: Risk optimization returned None.
# Processing flight KAFW to KBWI...
# Skipping Flight KAFW to KBWI: Risk optimization returned None.
# Processing flight KDAL to KMFE...
# Skipping Flight KDAL to KMFE: Risk optimization returned None.
# Processing flight KAFW to KMHT...
# Skipping Flight KAFW to KMHT: Risk optimization returned None.
# Processing flight KDFW to KIND...
# Skipping Flight KDFW to KIND: Risk optimization returned None.
# Processing flight KAFW to KMQY...
# Skipping Flight KAFW to KMQY: Risk optimization returned None.
# Processing flight KDFW to PANC...
# Skipping Flight KDFW to PANC: Risk optimization returned None.
# Processing flight KAFW to KOMA...
# Skipping Flight KAFW to KOMA: Risk optimization returned None.
# Processing flight KDFW to KOAK...
# Processing flight KDFW to KATL...
# Skipping Flight KDFW to KATL: Risk optimization returned None.
# Processing flight KDFW to TJBQ...
# Skipping Flight KDFW to TJBQ: Risk optimization returned None.
# Processing flight KDFW to KTPA...
# Skipping Flight KDFW to KTPA: Risk optimization returned None.
# Processing flight KAFW to KBFM...
# Processing flight KDFW to KLFT...
# Skipping Flight KDFW to KLFT: Risk optimization returned None.
# Processing flight KDFW to KLBB...
# Skipping Flight KDFW to KLBB: Risk optimization returned None.
# Processing flight KAFW to KPHX...
# Skipping Flight KAFW to KPHX: Risk optimization returned None.
# Processing flight KAFW to KMCO...
# Skipping Flight KAFW to KMCO: Risk optimization returned None.
# Processing flight KDFW to KPNS...
# Skipping Flight KDFW to KPNS: Risk optimization returned None.
# Processing flight KAFW to KSJC...
# Processing flight KAFW to KSDF...
# Skipping Flight KAFW to KSDF: Risk optimization returned None.
# Processing flight KDAL to MMQT...
# Processing flight KAFW to KSHV...
# Skipping Flight KAFW to KSHV: Risk optimization returned None.
# Processing flight KDFW to KSUU...
# Skipping Flight KDFW to KSUU: Risk optimization returned None.
# Processing flight KAFW to KOPF...
# Skipping Flight KAFW to KOPF: Risk optimization returned None.
# Processing flight KAFW to KDEN...
# Skipping Flight KAFW to KDEN: Risk optimization returned None.
# Processing flight KAFW to KAMA...
# Skipping Flight KAFW to KAMA: Risk optimization returned None.
# Processing flight KDFW to KIAH...
# Processing flight KAFW to KORD...
# Skipping Flight KAFW to KORD: Risk optimization returned None.
# Processing flight KAFW to KAUS...
# Skipping Flight KAFW to KAUS: Likelihood optimization returned None.
# Processing flight KAFW to KLRD...
# Skipping Flight KAFW to KLRD: Risk optimization returned None.
# Processing flight KAFW to KELP...
# Skipping Flight KAFW to KELP: Risk optimization returned None.
# Processing flight KDAL to KTOL...
# Skipping Flight KDAL to KTOL: Risk optimization returned None.
# Processing flight KAFW to KRNO...
# Skipping Flight KAFW to KRNO: Risk optimization returned None.
# Processing flight KAFW to KMSP...
# Skipping Flight KAFW to KMSP: Risk optimization returned None.
# Processing flight KAFW to KDRT...
# Skipping Flight KAFW to KDRT: Risk optimization returned None.
# Processing flight KAFW to KSFO...
# Skipping Flight KAFW to KSFO: Risk optimization returned None.
# Processing flight KAFW to KLAX...
# Processing flight KDFW to KDOV...
# Processing flight KAFW to KSAN...
# Skipping Flight KAFW to KSAN: Risk optimization returned None.
# Processing flight KAFW to KPHL...
# Skipping Flight KAFW to KPHL: Risk optimization returned None.
# Processing flight KDFW to KLIT...
# Processing flight KAFW to KSEA...
# Skipping Flight KAFW to KSEA: Risk optimization returned None.
# Processing flight KDFW to KSAT...
# Skipping Flight KDFW to KSAT: Risk optimization returned None.
# Processing flight KAFW to KAFW...
# CasADi - 2025-03-06 10:27:00 WARNING("solver:nlp_grad_f failed: NaN detected for output grad_f_x, at (row 8, col 0).") [.../casadi/core/oracle_function.cpp:393]
# CasADi - 2025-03-06 10:27:00 WARNING("solver:nlp_grad_f failed: NaN detected for output grad_f_x, at (row 8, col 0).") [.../casadi/core/oracle_function.cpp:393]
# Skipping Flight KAFW to KAFW: Risk optimization returned None.
# Processing flight KDAL to KYIP...
# Skipping Flight KDAL to KYIP: Risk optimization returned None.
# Processing flight KDAL to KMQY...
# Skipping Flight KDAL to KMQY: Risk optimization returned None.
# Processing flight KDAL to KMRC...
# Skipping Flight KDAL to KMRC: Risk optimization returned None.
# Processing flight KDAL to KSAT...
# Skipping Flight KDAL to KSAT: Risk optimization returned None.
# Processing flight KDFW to KJAX...
# Processing flight KDFW to KMCO...
# Skipping Flight KDFW to KMCO: Risk optimization returned None.
# Processing flight KDFW to KPHX...
# Processing flight KAFW to KPDX...
# Skipping Flight KAFW to KPDX: Risk optimization returned None.
# Processing flight KDFW to KSDF...
# Skipping Flight KDFW to KSDF: Risk optimization returned None.
# Processing flight KDFW to KSJC...
# Processing flight KDFW to KSHV...
# Skipping Flight KDFW to KSHV: Risk optimization returned None.
# Processing flight KDFW to KDEN...
# Skipping Flight KDFW to KDEN: Risk optimization returned None.
# Processing flight KDAL to KCNO...
# Processing flight KAFW to KSBD...
# Processing flight KDFW to KORD...
# Skipping Flight KDFW to KORD: Risk optimization returned None.
# Processing flight KAFW to KRFD...
# Processing flight KAFW to KIAG...
# Skipping Flight KAFW to KIAG: Risk optimization returned None.
# Processing flight KDFW to KAUS...
# Skipping Flight KDFW to KAUS: Likelihood optimization returned None.
# Processing flight KDFW to KBFI...
# Skipping Flight KDFW to KBFI: Risk optimization returned None.
# Processing flight KDFW to KLRD...
# Skipping Flight KDFW to KLRD: Risk optimization returned None.
# Processing flight KDFW to KELP...
# Skipping Flight KDFW to KELP: Fuel optimization returned None.
# Processing flight KAFW to KICT...
# Skipping Flight KAFW to KICT: Risk optimization returned None.
# Processing flight KDFW to KMSP...
# Skipping Flight KDFW to KMSP: Risk optimization returned None.
# Processing flight KDAL to KLRD...
# Skipping Flight KDAL to KLRD: Risk optimization returned None.
# Processing flight KDAL to KELP...
# Skipping Flight KDAL to KELP: Risk optimization returned None.
# Processing flight KDFW to KTIK...
# Skipping Flight KDFW to KTIK: Risk optimization returned None.
# Processing flight KDFW to KPHL...
# Skipping Flight KDFW to KPHL: Risk optimization returned None.
# Processing flight KAFW to KFWA...
# Skipping Flight KAFW to KFWA: Risk optimization returned None.
# Processing flight KAFW to KTUL...
# Skipping Flight KAFW to KTUL: Risk optimization returned None.
# Processing flight KDFW to KSEA...
# Skipping Flight KDFW to KSEA: Risk optimization returned None.
# Processed 23/147 flights successfully.
# Success Rate: 15.65%

# %% [markdown]
# **Saving File**

# %%
def save_flight_results(df, fuel_burns_by_regime, time_in_flight_by_regime, output_file):
    # Create a list to store results
    results_list = []

    # Loop through stored results and construct rows
    for index, row in df.iterrows():
        origin = row["Origin"]
        destination = row["Destination"]

        for regime in ["fuel", "likelihood", "risk"]:
            if regime in fuel_burns_by_regime and regime in time_in_flight_by_regime:
                if index < len(fuel_burns_by_regime[regime]) and index < len(time_in_flight_by_regime[regime]):
                    fuel_burn = fuel_burns_by_regime[regime][index]
                    time = time_in_flight_by_regime[regime][index]
                else:
                    fuel_burn = "NA"
                    time = "NA"
            else:
                fuel_burn = "NA"
                time = "NA"

            results_list.append([origin, destination, regime, fuel_burn, time])

    # Convert to DataFrame
    final_results_df = pd.DataFrame(results_list, columns=["origin", "destination", "regime", "fuel burn", "time"])

    # Save to CSV
    final_results_df.to_csv(output_file, index=False)
    
    print(f"Results saved to {output_file}")

# Define the output file path
output_file = "data/results/40dB/40_fuel_burn_results.csv"

# Call the function to save results
save_flight_results(df, fuel_burns_by_regime, time_in_flight_by_regime, output_file)
# Out:
# Results saved to /Users/vantran/Documents/thesis/code/50_flight_optimization_results_no_time.csv
